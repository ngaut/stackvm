# %%
from app.controller.label_classifier import LabelClassifier, get_labels_tree, get_labels_tree_with_task_goals

classifer = LabelClassifier()

# %%
labels_tree_with_task = get_labels_tree_with_task_goals()
labels_tree_with_task
# Out:
# [{'name': 'Basic Knowledge',
#   'description': 'Queries about simple facts or common knowledge, such as Concept Explanation, Feature Support.',
#   'children': [{'name': 'Feature Support',
#     'description': 'Information about the features supported by TiDB, including capabilities and limitations.',
#     'children': [{'name': 'RU',
#       'description': 'A unit of measurement used to quantify the resource consumption of queries or transactions. It helps in evaluating system performance and optimizing resource allocation.',
#       'children': [],
#       'tasks': [{'id': '175ab194-0516-44de-8255-5d5025669720',
#         'goal': 'What are the key indicators or metrics to consider when adjusting RU allocation in TiDB Cloud?'}]},
#      {'name': 'TiCDC',
#       'description': '',
#       'children': [],
#       'tasks': [{'id': '50097f76-e8ed-4d1b-93ae-750d6c588713',
#         'goal': 'drainer投递到Kafka的数据是什么格式？'}]}],
#     'tasks': [{'id': '00e4bbcc-1b29-421a-9769-4a6ea4fe24f2',
#       'goal': 'Does TiDB support FOREIGN KEY constraints?'},
#      {'id': '4db8ec8b-011b-415e-855b-0ca5ccd2afb5',
#       'goal': 'TiDB 是否支持平滑升级？请提供详细信息。'}]},
#    {'name': 'Use Cases',
#     'description': 'Examples and scenarios where TiDB is utilized, demonstrating its applications in various contexts.',
#     'children': [],
#     'tasks': [{'id': '0de8d21f-9124-4cae-b1ae-e95fc71328e6',
#       'goal': 'Who uses TiDB?'},
#      {'id': 'e96d2d00-87f9-4e06-80ab-4aef5990513f',
#       'goal': 'Which two fintech companies are using TiDB?'}]},
#    {'name': 'Version Release',
#     'description': "Details about TiDB's version updates, including new features, improvements, and fixes in each release.",
#     'children': [],
#     'tasks': [{'id': '373b266a-e44f-4054-bd96-a7dc09b2f256',
#       'goal': "What's new in TiDB version 8.1.0?"},
#      {'id': '4aa8c45c-4294-43b9-9b1d-bce1ce70f610',
#       'goal': "What's the latest version of TiDB?"}]}],
#   'tasks': []},
#  {'name': 'Operation Guide',
#   'description': 'Looking for step-by-step instructions to perform specific operations. Covers topics like deployment procedures, feature configuration, and maintenance tasks.',
#   'children': [{'name': 'Dumpling',
#     'description': '',
#     'children': [],
#     'tasks': [{'id': 'c041e7ac-3eb5-4853-bbe0-4d2279925dd3',
#       'goal': 'Can you explain how to interpret the results generated by Dumpling when it creates multiple files? Additionally, how can I use these files to import data into my TiDB cluster? Please provide examples.'}]},
#    {'name': 'Deployment',
#     'description': 'Inquiries the deployment guide of a specific product.',
#     'children': [],
#     'tasks': [{'id': '5134da30-a102-43db-b730-523f934ff382',
#       'goal': 'What is the minimal deployment topology required for a resilient TiDB cluster?'}]},
#    {'name': 'Basic Operations',
#     'description': 'Instructions and information on performing fundamental operations within TiDB, such as upgrading and version checking',
#     'children': [],
#     'tasks': [{'id': '1e140e0f-f32a-4cd4-8c80-869af62a3359',
#       'goal': 'How can I upgrade TiUP to the latest version?'},
#      {'id': '4e0e79df-215f-4f57-ac87-2998887b087b',
#       'goal': 'How can I determine the version of TiDB that I am using?'}]},
#    {'name': 'SQL Generation',
#     'description': 'Guidance on writing or generating SQL statements to perform specific tasks, such as data partitioning, query optimization, and schema design. Includes examples and best practices.',
#     'children': [],
#     'tasks': [{'id': 'd30be387-f053-4b3b-9445-c1afdc6fbb4f',
#       'goal': 'How can I use the split syntax to divide partition 1 of a partitioned table, where the primary key is session_key, into 1000 regions using session_key as a UUID?'}]},
#    {'name': 'Data Migration',
#     'description': 'Strategies and tools for migrating data to TiDB, including large-scale migrations and handling multiple databases.',
#     'children': [],
#     'tasks': [{'id': '1054e488-fc44-4742-855a-4757324e845d',
#       'goal': 'How can I quickly import a CSV file into TiDB?'}]}],
#   'tasks': []},
#  {'name': 'Troubleshooting',
#   'description': 'Diagnostic guidance and problem-solving approaches for system issues, error conditions, or unexpected behaviors. Focuses on root cause analysis and resolution strategies for common operational challenges.',
#   'children': [],
#   'tasks': []},
#  {'name': 'Complex Task Planning',
#   'description': 'Strategic planning and implementation guidance for sophisticated, multi-phase technical projects. Covers system design decisions and large-scale operational changes.',
#   'children': [{'name': 'Research & Analysis',
#     'description': 'In-depth research and analytical comparisons related to product features, performance, and design.',
#     'children': [{'name': 'Comparative Analysis',
#       'description': 'Detailed analysis and comparison of different designs, different version or the same features across different products. Includes evaluating trade-offs between various approaches and comparing implementation strategies.',
#       'children': [{'name': 'Version Comparison',
#         'description': '',
#         'children': [],
#         'tasks': [{'id': '8ece15be-9408-4744-b80b-9b2127bbb223',
#           'goal': 'What are the differences between TiDB 7.0 and TiDB 8.0?'}]}],
#       'tasks': [{'id': '03d4a7f8-5610-4e87-af0f-91349b82a4d7',
#         'goal': 'Has anyone implemented TiDB to replace Elasticsearch for high-QPS interfaces with simple single-table queries, and how does the performance compare after the modification?'}]},
#      {'name': 'Technical Design',
#       'description': 'Detailed information about the technical design aspects of system, including scalability, search functionalities, and architecture.',
#       'children': [{'name': 'Full Text Search',
#         'description': '',
#         'children': [],
#         'tasks': [{'id': '627fd26e-95a8-4bbf-869c-49daf871ce1e',
#           'goal': 'write a blog about FTS in database, key idea: mainstream RDBMS is lack of inverted index support, but FTS is quiet a requirement, so we have to introduce something like ES, but that generate extra complexity of the architecture,  if we can add FTS into distributed database, that would be nice, '}]},
#        {'name': 'Scalability',
#         'description': '',
#         'children': [],
#         'tasks': [{'id': '8cd87cd2-9b84-48b0-af2b-f43b4140ac1c',
#           'goal': 'What is the scalability of TiDB?'}]},
#        {'name': 'TiDB Vector Search',
#         'description': '',
#         'children': [],
#         'tasks': [{'id': '2ea25e72-7c72-4c77-ab87-ee55806d99da',
#           'goal': 'How is vector search used?'},
#          {'id': 'fcfe4fa8-a033-4ac6-a43b-4d0c1eab2f15',
#           'goal': 'How is vector search implemented in TiDB?'}]},
#        {'name': 'Multi-Tenancy Architecture',
#         'description': '',
#         'children': [],
#         'tasks': [{'id': '1863ae73-329b-4bb2-a345-13dfd7bf1a3c',
#           'goal': 'What makes TiDB a good choice for SaaS, especially for multi-tenancy architecture?'}]}],
#       'tasks': []},
#      {'name': 'Product Overview',
#       'description': 'Comprehensive overview of TiDB, covering its technical aspects, use cases, and product-specific details.',
#       'children': [],
#       'tasks': [{'id': '4a05a7d9-84d3-4f11-a6fd-bd98c6bd1751',
#         'goal': 'What is TiDB?'},
#        {'id': '533bcc65-0159-4db2-a508-5f8ea6eaffeb',
#         'goal': 'What is TiCDC?'}]}],
#     'tasks': []},
#    {'name': 'Step-by-Step Execution',
#     'description': '',
#     'children': [{'name': 'Performance Analysis',
#       'description': '',
#       'children': [],
#       'tasks': [{'id': '05f32bab-5dc8-4226-a9e6-99c8093735b3',
#         'goal': 'Summarize the performance profile of the newest version of TiDB and attach a report download link at the end of the report'}]}],
#     'tasks': []}],
#   'tasks': []},
#  {'name': 'Other Topics',
#   'description': "General technical discussions and queries that don't fit into the other categories.",
#   'children': [],
#   'tasks': [{'id': '8510ee91-729c-43de-afb1-4e81b9b64e9e',
#     'goal': 'What can you do?'}]}]

# %%
from app.controller.label_classifier import find_longest_matching_node, get_all_tasks_under_node, get_task_plans

labels = [
    {
        "label": "Basic Knowledge",
        "description": "Queries about simple facts or common knowledge, such as Concept Explanation, Feature Support."
    }
]

matching_node = find_longest_matching_node(labels_tree_with_task, labels)
tasks = get_all_tasks_under_node(matching_node)
tasks_plan = get_task_plans([task["id"] for task in tasks])
tasks_plan
# Out:
# {'00e4bbcc-1b29-421a-9769-4a6ea4fe24f2': {'goal': 'Does TiDB support FOREIGN KEY constraints?',
#   'best_plan': [{'parameters': {'chain_of_thoughts': "To determine if TiDB supports FOREIGN KEY constraints, we will follow a structured approach: 1. Use the knowledge graph to retrieve any relevant information about TiDB's support for FOREIGN KEY constraints. 2. Use vector search to gather detailed documentation or discussions about TiDB's features related to FOREIGN KEY constraints. 3. Synthesize the information gathered to provide a clear answer, including citations from the sources.",
#      'dependency_analysis': 'Step 1 and Step 2 are independent. Step 3 depends on the information gathered from Steps 1 and 2.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['foreign_key_support_graph'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'TiDB FOREIGN KEY constraints support'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['foreign_key_support_docs'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'TiDB support for FOREIGN KEY constraints',
#       'top_k': 3}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['final_answer'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': 'Knowledge graph data: ${foreign_key_support_graph}\nDocuments: ${foreign_key_support_docs}',
#       'prompt': 'Based on the provided knowledge graph data and documents, determine if TiDB supports FOREIGN KEY constraints. Provide a detailed explanation of the support status, including any limitations or conditions, and cite the sources. Respond in English.'}},
#     'seq_no': 3,
#     'type': 'calling'}]},
#  '0de8d21f-9124-4cae-b1ae-e95fc71328e6': {'goal': 'Who uses TiDB?',
#   'best_plan': [{'parameters': {'chain_of_thoughts': 'To identify who uses TiDB, we will follow a structured approach: 1. Use a knowledge graph to gather structured information about TiDB users. 2. Use vector search to retrieve detailed information from unstructured data sources. 3. Synthesize the information to provide a comprehensive list of TiDB users. This approach ensures we capture both well-documented and less formalized use cases.',
#      'dependency_analysis': 'Step 1 retrieves structured data about TiDB users. Step 2 gathers additional details from unstructured sources. Step 3 synthesizes the information from Steps 1 and 2.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['tidb_users_graph'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'Who uses TiDB?'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['tidb_users_vector'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'Companies and organizations using TiDB',
#       'top_k': 5}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['tidb_users_list'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': 'Knowledge Graph Data: ${tidb_users_graph}\nVector Search Data: ${tidb_users_vector}',
#       'prompt': 'Based on the following data, provide a detailed list of companies and organizations that use TiDB. Include any notable use cases or industries where TiDB is applied. Please ensure that the generated text uses English.'}},
#     'seq_no': 3,
#     'type': 'calling'},
#    {'parameters': {'final_answer': '${tidb_users_list}'},
#     'seq_no': 4,
#     'type': 'assign'}]},
#  '175ab194-0516-44de-8255-5d5025669720': {'goal': 'What are the key indicators or metrics to consider when adjusting RU allocation in TiDB Cloud?',
#   'best_plan': [{'parameters': {'chain_of_thoughts': 'To determine the key indicators or metrics for adjusting RU allocation in TiDB Cloud, we will follow a structured approach: 1. Gather information on how RU allocation works in TiDB Cloud. 2. Identify specific metrics relevant to monitoring and adjusting RU allocation. 3. Analyze best practices for resource allocation in distributed databases. 4. Synthesize the information to provide a comprehensive list of key indicators.',
#      'dependency_analysis': 'Step 2 depends on Step 1. Step 3 depends on Step 2. Step 4 synthesizes all previous steps.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['ru_allocation_info'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'How RU allocation works in TiDB Cloud',
#       'top_k': 3}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['tidb_cloud_metrics'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'Key metrics for monitoring and adjusting RU allocation in TiDB Cloud',
#       'top_k': 3}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['resource_allocation_best_practices'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'Best practices for resource allocation in distributed databases',
#       'top_k': 3}},
#     'seq_no': 3,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['key_indicators'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': 'RU Allocation Info: ${ru_allocation_info}\nTiDB Cloud Metrics: ${tidb_cloud_metrics}\nBest Practices: ${resource_allocation_best_practices}',
#       'prompt': 'Based on the gathered information, list the key indicators or metrics to consider when adjusting RU allocation in TiDB Cloud. Please ensure that the generated text uses English.'}},
#     'seq_no': 4,
#     'type': 'calling'},
#    {'parameters': {'final_answer': '${key_indicators}'},
#     'seq_no': 5,
#     'type': 'assign'}]},
#  '373b266a-e44f-4054-bd96-a7dc09b2f256': {'goal': "What's new in TiDB version 8.1.0?",
#   'best_plan': [{'parameters': {'chain_of_thoughts': "To determine what's new in TiDB version 8.1.0, we will follow a structured approach: 1. Use the knowledge graph to retrieve information about TiDB version 8.1.0. 2. Use vector search to gather detailed information about the new features and improvements in this version. 3. Synthesize the information into a comprehensive answer in Chinese. This approach ensures that we gather both structured and detailed information about the version.",
#      'dependency_analysis': 'Step 2 depends on Step 1. Step 3 depends on Step 2.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['tidb_8_1_0_graph'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'TiDB version 8.1.0'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['tidb_8_1_0_features'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'TiDB 8.1.0 新功能和改进', 'top_k': 5}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['final_answer'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': None,
#       'prompt': '请总结 TiDB 8.1.0 版本的新功能和改进。结合以下信息：\n1. 知识图谱信息：${tidb_8_1_0_graph}\n2. 详细特性信息：${tidb_8_1_0_features}\n\n请确保生成的文本使用中文。'}},
#     'seq_no': 3,
#     'type': 'calling'}]},
#  '4aa8c45c-4294-43b9-9b1d-bce1ce70f610': {'goal': "What's the latest version of TiDB?",
#   'best_plan': [{'parameters': {'chain_of_thoughts': 'To find the latest version of TiDB and provide the answer in Chinese, we will follow these steps: 1. Use the knowledge graph to retrieve the latest stable version of TiDB. 2. Use the LLM to extract the version number from the knowledge graph data. 3. Formulate the final answer in Chinese, including the version number and source citation.',
#      'dependency_analysis': 'Step 1 retrieves the version information. Step 2 processes this information to extract the version number. Step 3 uses the extracted data to formulate the final answer.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['tidb_version_graph'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'TiDB latest stable version'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['latest_stable_tidb_version',
#       'release_date'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': 'the retrieved knowledge graph data:\n${tidb_version_graph}',
#       'prompt': '从提供的知识图数据中提取 TiDB 的最新稳定版本号。\n\n- 关注与“发布说明”相关的实体。\n- 如果找到多个版本号，选择发布日期最近的一个。\n- 版本号可能是 \'vX.Y.Z\' 或 \'vX.Y.Z-suffix\' 格式（例如 \'v8.3.0-DMR\'）。\n\n- 仅以 JSON 格式响应，包含键 ["latest_stable_tidb_version", "release_date"]，例如 {"latest_stable_tidb_version": "v8.1.1", "release_date": "2024-08-27"}\n- 如果未找到特定的稳定版本号，响应为 {"latest_stable_tidb_version": "latest stable version tidb", "release_date": null}。'}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'final_answer': 'TiDB 的最新稳定版本是 ${latest_stable_tidb_version}。有关详细信息，请参阅发布说明：${source_uri}',
#      'source_uri': 'https://pingcap.com/docs/stable/release-notes/'},
#     'seq_no': 3,
#     'type': 'assign'}]},
#  '4db8ec8b-011b-415e-855b-0ca5ccd2afb5': {'goal': 'TiDB 是否支持平滑升级？请提供详细信息。',
#   'best_plan': [{'parameters': {'chain_of_thoughts': "To determine if TiDB supports smooth upgrades, we will follow a structured approach: 1. Use the knowledge graph to gather information about TiDB's upgrade capabilities. 2. Use vector search to find detailed documentation or user experiences related to smooth upgrades in TiDB. 3. Synthesize the information to provide a comprehensive answer.",
#      'dependency_analysis': "Step 1 will gather general information about TiDB's upgrade capabilities. Step 2 will provide detailed insights and examples. Step 3 will synthesize the information into a final answer."},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['tidb_upgrade_info'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'TiDB smooth upgrade support'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['upgrade_details'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'TiDB smooth upgrade process and user experiences',
#       'top_k': 5}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['detailed_answer'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': None,
#       'prompt': '根据以下信息，回答 TiDB 是否支持平滑升级，并提供详细信息：\n1. TiDB 升级信息：${tidb_upgrade_info}\n2. 升级细节：${upgrade_details}\n请确保生成的文本使用中文。'}},
#     'seq_no': 3,
#     'type': 'calling'},
#    {'parameters': {'final_answer': '${detailed_answer}'},
#     'seq_no': 4,
#     'type': 'assign'}]},
#  '50097f76-e8ed-4d1b-93ae-750d6c588713': {'goal': 'drainer投递到Kafka的数据是什么格式？',
#   'best_plan': [{'parameters': {'chain_of_thoughts': 'To determine the format of data delivered by drainer to Kafka, we will follow a structured approach: 1. Use the knowledge graph to gather information about drainer and its interaction with Kafka. 2. Use vector search to retrieve detailed documentation or examples of data formats used by drainer when delivering to Kafka. 3. Synthesize the information to provide a clear answer in Chinese, including necessary citations.',
#      'dependency_analysis': 'Step 1 will provide a general understanding of drainer and Kafka interaction. Step 2 will provide specific examples or documentation. Step 3 will synthesize the information into a final answer.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['drainer_kafka_knowledge'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'drainer Kafka data format'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['drainer_kafka_examples'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'drainer Kafka data format example',
#       'top_k': 3}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['final_answer'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': '知识图谱信息: ${drainer_kafka_knowledge}\n示例文档: ${drainer_kafka_examples}',
#       'prompt': '根据以下信息，描述drainer投递到Kafka的数据格式，并提供必要的引用。请确保生成的文本使用中文。'}},
#     'seq_no': 3,
#     'type': 'calling'}]},
#  'e96d2d00-87f9-4e06-80ab-4aef5990513f': {'goal': 'Which two fintech companies are using TiDB?',
#   'best_plan': [{'parameters': {'chain_of_thoughts': "To identify which two fintech companies are using TiDB, we will follow a structured approach: 1. Use the knowledge graph to find any direct associations between TiDB and fintech companies. 2. Use vector search to gather additional information about TiDB's usage in the fintech sector. 3. Synthesize the information to identify two fintech companies using TiDB. This approach ensures we leverage both structured and unstructured data sources for comprehensive results.",
#      'dependency_analysis': 'Step 1 will retrieve initial data from the knowledge graph. Step 2 will use vector search to gather more context. Step 3 will synthesize the results from steps 1 and 2.'},
#     'seq_no': 0,
#     'type': 'reasoning'},
#    {'parameters': {'output_vars': ['fintech_tidb_knowledge'],
#      'tool_name': 'retrieve_knowledge_graph',
#      'tool_params': {'query': 'Fintech companies using TiDB'}},
#     'seq_no': 1,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['fintech_tidb_vector'],
#      'tool_name': 'vector_search',
#      'tool_params': {'query': 'Which fintech companies are using TiDB?',
#       'top_k': 5}},
#     'seq_no': 2,
#     'type': 'calling'},
#    {'parameters': {'output_vars': ['identified_fintech_companies'],
#      'tool_name': 'llm_generate',
#      'tool_params': {'context': None,
#       'prompt': 'Based on the following data, identify two fintech companies that are using TiDB. Provide the answer in text format with necessary citations from the source_uri.\n\nKnowledge Graph Data: ${fintech_tidb_knowledge}\nVector Search Data: ${fintech_tidb_vector}\n\nPlease ensure that the generated text uses English.'}},
#     'seq_no': 3,
#     'type': 'calling'},
#    {'parameters': {'final_answer': '${identified_fintech_companies}'},
#     'seq_no': 4,
#     'type': 'assign'}]}}

# %%
from typing import Dict, Any, List

def format_tasks_pans(
    node: Dict[str, Any],
    task_plans: Dict[str, Dict[str, Any]],
    current_path: List[str] = None
) -> str:
    """
    Traverses the tree structure and formats each task into a specified text format.

    Parameters:
    - node (Dict[str, Any]): The current node in the tree.
    - task_plans (Dict[str, Dict[str, Any]]): A dictionary mapping task IDs to their best plans.
    - current_path (List[str], optional): The path of labels from the root to the current node.

    Returns:
    - str: The formatted text containing all tasks.
    """
    if current_path is None:
        current_path = []

    output = []

    # Update the current path with the current node's name
    node_name = node.get("name", "")
    new_path = current_path + [node_name] if node_name else current_path

    # Process tasks in the current node
    tasks = node.get("tasks", [])
    for task in tasks:
        task_id = task.get("id")
        task_goal = task.get("goal")
        best_plan = task_plans.get(task_id, {}).get("best_plan",  None)
        if best_plan is None:
            continue

        task_text = (
            f"task: {task_goal}\n"
            f"label_path: {' -> '.join(new_path)}\n"
            f"best_plan: {best_plan}\n"
            "-------\n"
        )
        output.append(task_text)

    # Recursively process child nodes
    children = node.get("children", [])
    for child in children:
        output.append(format_tasks_pans(child, task_plans, new_path))

    return ''.join(output)

# %%
from app.services.llm_interface import LLMInterface
from app.config.settings import LLM_PROVIDER, FAST_LLM_MODEL
from app.services import get_best_pratices_prompt


formatted_task_plan =  format_tasks_pans(matching_node, tasks_plan)
label_path = ' -> '.join([label["label"] for label in labels])
prompt = get_best_pratices_prompt(label_path, formatted_task_plan)

best_pratices_str = LLMInterface(LLM_PROVIDER, FAST_LLM_MODEL).generate(prompt)
print(best_pratices_str)
# Out:
# ### Analysis of Task Plans in the Basic Knowledge Category
#
# #### Common Patterns and Best Practices
#
# 1. **Structured Approach**: Each task plan follows a systematic methodology, often broken down into a series of logical steps. This structured approach ensures that all necessary information is gathered before synthesizing a final answer.
#
# 2. **Use of Multiple Information Sources**: The plans consistently utilize a combination of tools:
#    - **Knowledge Graph Retrieval**: This is used to obtain structured, reliable information about the subject matter.
#    - **Vector Search**: This tool is employed to gather unstructured data, such as documentation or user experiences, which provides depth and context to the answers.
#    - **LLM Generation**: The final synthesis of information is often done using a language model, which helps articulate the findings in a coherent manner.
#
# 3. **Dependency Analysis**: Each plan includes a clear dependency analysis, indicating which steps are independent and which rely on the outputs of previous steps. This helps in understanding the flow of information and ensures that the task is executed efficiently.
#
# 4. **Synthesis of Information**: After gathering data from various sources, the plans emphasize synthesizing this information into a comprehensive answer. This is crucial for providing a well-rounded response that addresses the user's query thoroughly.
#
# 5. **Language and Format Considerations**: Some tasks specify the language in which the final answer should be generated (e.g., English or Chinese), ensuring that the output is tailored to the audience's needs.
#
# #### Meta-Thinking and Planning Schemas
#
# 1. **Goal-Oriented Planning**: Each task is framed with a clear objective, guiding the selection of tools and the structure of the inquiry. This goal-oriented mindset helps maintain focus throughout the task.
#
# 2. **Iterative Information Gathering**: The plans reflect an iterative process where information is gathered, analyzed, and then synthesized. This iterative approach allows for refining the understanding of the topic as more data is collected.
#
# 3. **Integration of Structured and Unstructured Data**: The combination of structured data (from knowledge graphs) and unstructured data (from vector searches) is a key schema that enhances the richness of the final output.
#
# 4. **Conditional Logic**: The plans often include conditional logic in the form of dependency analysis, which helps in determining the sequence of actions based on the availability of information.
#
# #### Efficiency and Effectiveness
#
# 1. **Minimizing Redundant Steps**: By clearly defining dependencies and using a structured approach, the plans minimize redundant actions, leading to a more efficient task execution.
#
# 2. **Focused Information Retrieval**: The use of specific queries in knowledge graph retrieval and vector searches ensures that the information gathered is relevant and directly applicable to the task at hand.
#
# 3. **Clear Output Formulation**: The final answers are formulated in a clear and concise manner, often including citations or references to the sources of information. This not only enhances credibility but also provides users with pathways for further exploration.
#
# 4. **Adaptability**: The plans are adaptable to various types of inquiries within the Basic Knowledge category, demonstrating a flexible framework that can be applied to different contexts.
#
# ### Summary of Key Best Practices and Planning Schemas
#
# - **Adopt a Structured Approach**: Break down tasks into clear, logical steps to ensure thoroughness and clarity.
# - **Utilize Multiple Data Sources**: Combine structured and unstructured data to enrich the information base.
# - **Conduct Dependency Analysis**: Understand the relationships between different steps to optimize the flow of information.
# - **Synthesize Information Effectively**: Focus on integrating data from various sources to provide comprehensive answers.
# - **Tailor Outputs to Audience Needs**: Consider language and format requirements in the final output.
# - **Iterate and Refine**: Use an iterative process to gather and analyze information, allowing for adjustments based on new insights.
#
# By following these best practices and planning schemas, individuals can efficiently and effectively tackle similar tasks in the Basic Knowledge category, ensuring high-quality outcomes.

# %%
best_pratices_str = """ To solve tasks in the <Basic Knowledge> category, please follow this approach:
1.	Breakdown the goal into small question (if Necessary):
  - Purpose: Break down complex questions into smaller sub-questions to ensure all aspects are thoroughly covered.
  - Note: For straightforward questions, you can skip this step and proceed directly.

2. Simultaneously Use Multiple Search Tools to Retrieve Information:
  - Knowledge Graph Search: Obtain structured, high-level information.
  - Vector Search: Retrieve detailed, unstructured documents and examples.
  - Strategy: Use both search tools simultaneously for each (sub) question to ensure comprehensive information gathering.

3. Use LLM to Generate the Final Answer:
  - Integrate Information: Compile all the retrieved data.
  - Generate Answer: Utilize the LLM to summarize the information, producing an accurate and coherent response.

Essence Summary:

- Comprehensive Retrieval Enhances Information Coverage: By simultaneously using knowledge graph search and vector search, you gather rich and comprehensive information.
- Efficient Process with Simplified Steps: If needed, split the question, then proceed directly to information retrieval and answer generation, avoiding unnecessary procedures.
- Accurate Generation Ensures Answer Quality: Use the LLM to integrate the retrieved information, providing precise and valuable answers."""

# %%
from app.models.label import Label
from app.database import SessionLocal

with SessionLocal() as session:
    label = session.query(Label).filter(Label.name == labels[-1].get("label")).first()
    label.best_practices = best_pratices_str
    session.add(label)
    session.commit()
